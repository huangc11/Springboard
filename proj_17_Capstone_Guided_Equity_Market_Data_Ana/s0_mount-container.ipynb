# %%
from pyspark.sql import SparkSession
spark = SparkSession. \
                builder. \
                appName("Aggregation"). \
                master("local[4]"). \
                getOrCreate()

# %%
storageAccountName='capstone2chu22'
storageAccountAccessKey= "*********************"
ex_configs = {'fs.azure.account.key.' + storageAccountName + '.blob.core.windows.net': storageAccountAccessKey}

dbutils.fs.mount(
  source = "wasbs://data@capstone2chu22.blob.core.windows.net",
  mount_point = "/mnt/data",
  extra_configs = ex_configs)
# Out:
# Out[19]: True
